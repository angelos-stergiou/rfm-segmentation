# %% [markdown]
# ## K-Means Clustering

# %% [markdown]
# ### Set-Up

# %%
import polars as pl
import numpy as np
import pandas as pd

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score
from sklearn.model_selection import GridSearchCV

# import plotly.graph_objects as go
# import plotly.express as px
import matplotlib.pyplot as plt

import pyarrow as pa
from pathlib import Path

# %%
# define input path
input_path = Path("Data_Lake/Output/rfm_data.parquet")

# load cleaned dataset
print("Loading cleaned dataset...")
df = pl.read_parquet(input_path)
print(df.head())
# Out:
# Loading cleaned dataset...
# shape: (5, 6)
# ┌────────────┬─────────────────┬─────────┬───────────┬──────────┬───────────┐
# │ CustomerID ┆ RFM_Segment     ┆ Recency ┆ Frequency ┆ Monetary ┆ RFM_Score │
# │ ---        ┆ ---             ┆ ---     ┆ ---       ┆ ---      ┆ ---       │
# │ i64        ┆ str             ┆ i64     ┆ u32       ┆ f64      ┆ str       │
# ╞════════════╪═════════════════╪═════════╪═══════════╪══════════╪═══════════╡
# │ 16676      ┆ Loyal_Customers ┆ 24      ┆ 4         ┆ 1592.12  ┆ 334       │
# │ 16256      ┆ Lost Customers  ┆ 257     ┆ 1         ┆ 752.43   ┆ 113       │
# │ 13139      ┆ Champions       ┆ 7       ┆ 7         ┆ 5064.94  ┆ 444       │
# │ 17718      ┆ Lost Customers  ┆ 223     ┆ 1         ┆ 139.35   ┆ 111       │
# │ 15226      ┆ Lost Customers  ┆ 301     ┆ 1         ┆ 154.41   ┆ 111       │
# └────────────┴─────────────────┴─────────┴───────────┴──────────┴───────────┘

# %% [markdown]
# ### K-Means Cluster

# %% [markdown]
# #### Find Optimal k

# %%
def find_optimal_k(
    df,
    id_col="CustomerID",
    features=["Recency", "Frequency", "Monetary"],
    metrics=["inertia", "silhouette_scores"],
    show_plots=True,
):
    """
    Function to determine the optimal number of clusters for KMeans using the Elbow Method and Silhouette Score.

    Parameters:
        df (pd.DataFrame or pl.DataFrame): Input DataFrame containing customer data.
        id_col (str): Column name to be used as index.
        features (list): List of columns to use for clustering.
        metrics (list): Metrics to compute (options: "inertia", "silhouette_scores").
        show_plots (bool): Whether to display the plots.

    Returns:
        int: Optimal number of clusters based on the Elbow Method and Silhouette Score.
    """

    # Convert to pandas if it's a Polars DataFrame
    if hasattr(df, "to_pandas"):
        df = df.to_pandas()

    # Validate required columns
    required_cols = [id_col] + features
    missing_cols = [col for col in required_cols if col not in df.columns]
    if missing_cols:
        raise ValueError(f"Missing required columns: {missing_cols}")

    # Set index and select relevant features
    df_pandas = df.set_index(id_col)[features]

    # Standardize the data
    scaler = StandardScaler()
    df_scaled = scaler.fit_transform(df_pandas)

    # Determine the optimal k using the Elbow Method and Silhouette Score
    inertia = []
    silhouette_scores = []
    k_range = list(range(4, 10))  # Testing k from 4 to 9

    for k in k_range:
        kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
        kmeans.fit(df_scaled)
        if "inertia" in metrics:
            inertia.append(kmeans.inertia_)
        if "silhouette_scores" in metrics:
            silhouette_scores.append(silhouette_score(df_scaled, kmeans.labels_))

    # Elbow Method plot
    if show_plots and "inertia" in metrics:
        fig, ax = plt.subplots(figsize=(10, 6), facecolor="white")
        ax.set_facecolor("#f2f2f2")
        ax.plot(k_range, inertia, marker="o", color="blue", linewidth=2)
        ax.set_title("Elbow Method for Optimal k", fontsize=14, weight="bold")
        ax.set_xlabel("Number of Clusters (k)", fontsize=12)
        ax.set_ylabel("Inertia", fontsize=12)
        ax.grid(True, linestyle="--", alpha=0.5)
        ax.tick_params(labelsize=10)
        plt.tight_layout()
        plt.show()

    # Silhouette Score plot
    if show_plots and "silhouette_scores" in metrics:
        fig, ax = plt.subplots(figsize=(10, 6), facecolor="white")
        ax.set_facecolor("#f2f2f2")
        ax.plot(k_range, silhouette_scores, marker="o", color="green", linewidth=2)
        ax.set_title("Silhouette Score Analysis", fontsize=14, weight="bold")
        ax.set_xlabel("Number of Clusters (k)", fontsize=12)
        ax.set_ylabel("Silhouette Score", fontsize=12)
        ax.grid(True, linestyle="--", alpha=0.5)
        ax.tick_params(labelsize=10)
        plt.tight_layout()
        plt.show()

    # Determine the optimal number of clusters
    # Silhouette score is preferred as it measures cluster quality directly
    if "inertia" in metrics and "silhouette_scores" in metrics:
        optimal_k = k_range[silhouette_scores.index(max(silhouette_scores))]
    elif "inertia" in metrics:
        # fallback: no clear elbow detection, just flag it
        optimal_k = k_range[inertia.index(min(inertia))]
        print("Warning: using min inertia only — consider adding silhouette_scores")
    elif "silhouette_scores" in metrics:
        optimal_k = k_range[silhouette_scores.index(max(silhouette_scores))]
    else:
        raise ValueError("No valid metric provided for optimal k selection")

    return optimal_k

# %%
find_optimal_k(
    df=df,
    id_col="CustomerID",
    features=["Recency", "Frequency", "Monetary"],
    metrics=["inertia", "silhouette_scores"],
    show_plots=True,
)
# Out:
# 4

# %%
def grid_search_kmeans(
    df,
    id_col="CustomerID",
    features=["Recency", "Frequency", "Monetary"],
    param_grid=None,
    cv=5,
):
    """
    Perform grid search for K-Means clustering parameters to maximize silhouette score.

    Parameters:
        df (pd.DataFrame or pl.DataFrame): Input DataFrame.
        id_col (str): Column to use as index.
        features (list): Feature columns to use.
        param_grid (dict): KMeans hyperparameter grid.
        cv (int): Number of cross-validation folds.

    Returns:
        tuple: (best_params, best_estimator, best_silhouette_score)
    """

    # Default parameter grid
    if param_grid is None:
        param_grid = {
            "n_clusters": [4, 5, 6, 7, 8, 9, 10],
            "n_init": [10, 20, 50],
            "max_iter": [300, 500, 1000],
        }

    # Convert Polars to Pandas if needed
    if hasattr(df, "to_pandas"):
        df = df.to_pandas()

    # Validate required columns
    required_cols = [id_col] + features
    missing = [col for col in required_cols if col not in df.columns]
    if missing:
        raise ValueError(f"Missing columns in input DataFrame: {missing}")

    # Set index and select features
    df_selected = df.set_index(id_col)[features]

    # Scale data
    scaler = StandardScaler()
    df_scaled = scaler.fit_transform(df_selected)

    # Custom scoring: silhouette score
    def silhouette_scorer(estimator, X):
        labels = estimator.fit_predict(X)
        return silhouette_score(X, labels)

    # Grid search
    kmeans = KMeans(random_state=42)
    grid_search = GridSearchCV(
        kmeans, param_grid, scoring=silhouette_scorer, cv=cv, n_jobs=-1
    )
    grid_search.fit(df_scaled)

    # Best result
    best_estimator = grid_search.best_estimator_
    best_params = grid_search.best_params_
    best_score = silhouette_score(df_scaled, best_estimator.fit_predict(df_scaled))

    return best_params, best_estimator, best_score

# %%
# example if param_grid is not None - define a custom parameter grid
# custom_param_grid = {
#    "n_clusters": [3, 4, 5, 6],  # Only testing 4 cluster values
#    "n_init": [10, 50],  # Trying fewer `n_init` values
#    "max_iter": [500, 1000],  # Testing two `max_iter` values
#    "tol": [1e-3],  # Fixing tolerance to a single value
#    "algorithm": ["lloyd", "elkan"],  # Only using "elkan" optimization
#    "init": ["k-means++", "random"]  # Only using "k-means++" initialization
# }

# %%
best_params, best_estimator, best_score = grid_search_kmeans(
    df,
    id_col="CustomerID",
    features=["Recency", "Frequency", "Monetary"],
    param_grid=None,
    cv=5,
)

# %%
def fit_kmeans(df, id_col, features, best_params):
    """
    Fits KMeans with the best parameters and returns the dataset with cluster labels.

    Parameters:
        df (pd.DataFrame or pl.DataFrame): The dataset.
        id_col (str): The column to use as index.
        features (list): The feature columns to use.
        best_params (dict): Best parameters for KMeans.

    Returns:
        pl.DataFrame: Original data with cluster labels.
    """

    # Convert to pandas if needed
    if hasattr(df, "to_pandas"):
        df = df.to_pandas()

    # Validate required columns
    required_cols = [id_col] + features
    missing = [col for col in required_cols if col not in df.columns]
    if missing:
        raise ValueError(f"Missing required columns: {missing}")

    # Prepare features
    df_features = df.set_index(id_col)[features]

    # Standardize
    scaler = StandardScaler()
    df_scaled = scaler.fit_transform(df_features)

    # Fit KMeans and predict
    kmeans = KMeans(**best_params, random_state=42)
    df["Cluster"] = kmeans.fit_predict(df_scaled)

    # Reset index
    df.reset_index(inplace=True)

    # Convert to Polars
    return pl.from_pandas(df)

# %%
# fit kmeans clustering algorithm on the best parameters selected from GridSearch
k_means_output = fit_kmeans(
    df, "CustomerID", ["Recency", "Frequency", "Monetary"], best_params
)
k_means_output.head()
# Out:
# shape: (5, 8)
# ┌───────┬────────────┬─────────────────┬─────────┬───────────┬──────────┬───────────┬─────────┐
# │ index ┆ CustomerID ┆ RFM_Segment     ┆ Recency ┆ Frequency ┆ Monetary ┆ RFM_Score ┆ Cluster │
# │ ---   ┆ ---        ┆ ---             ┆ ---     ┆ ---       ┆ ---      ┆ ---       ┆ ---     │
# │ i64   ┆ i64        ┆ str             ┆ i64     ┆ u32       ┆ f64      ┆ str       ┆ i32     │
# ╞═══════╪════════════╪═════════════════╪═════════╪═══════════╪══════════╪═══════════╪═════════╡
# │ 0     ┆ 16676      ┆ Loyal_Customers ┆ 24      ┆ 4         ┆ 1592.12  ┆ 334       ┆ 0       │
# │ 1     ┆ 16256      ┆ Lost Customers  ┆ 257     ┆ 1         ┆ 752.43   ┆ 113       ┆ 3       │
# │ 2     ┆ 13139      ┆ Champions       ┆ 7       ┆ 7         ┆ 5064.94  ┆ 444       ┆ 0       │
# │ 3     ┆ 17718      ┆ Lost Customers  ┆ 223     ┆ 1         ┆ 139.35   ┆ 111       ┆ 3       │
# │ 4     ┆ 15226      ┆ Lost Customers  ┆ 301     ┆ 1         ┆ 154.41   ┆ 111       ┆ 3       │
# └───────┴────────────┴─────────────────┴─────────┴───────────┴──────────┴───────────┴─────────┘

# %%
# overview of cluster features to assign cluster names
k_means_output.group_by("Cluster").agg(
    pl.len().alias("Count"),
    pl.col("Recency").mean().round(2),
    pl.col("Frequency").mean().round(2),
    pl.col("Monetary").mean().round(2),
).sort(["Cluster", "Monetary"], descending=True)
# Out:
# shape: (4, 5)
# ┌─────────┬───────┬─────────┬───────────┬───────────┐
# │ Cluster ┆ Count ┆ Recency ┆ Frequency ┆ Monetary  │
# │ ---     ┆ ---   ┆ ---     ┆ ---       ┆ ---       │
# │ i32     ┆ u32   ┆ f64     ┆ f64       ┆ f64       │
# ╞═════════╪═══════╪═════════╪═══════════╪═══════════╡
# │ 3       ┆ 1098  ┆ 240.2   ┆ 1.54      ┆ 469.58    │
# │ 2       ┆ 196   ┆ 16.05   ┆ 21.57     ┆ 12703.14  │
# │ 1       ┆ 11    ┆ 5.36    ┆ 90.36     ┆ 121248.73 │
# │ 0       ┆ 2988  ┆ 40.92   ┆ 3.59      ┆ 1300.49   │
# └─────────┴───────┴─────────┴───────────┴───────────┘

# %%
# define the cluster-to-name mapping
cluster_names = {
    0: "Steady_Buyers",
    1: "VIP_Customers",
    2: "Elite_Spenders",
    3: "One_Time_Shoppers",
}

# assign cluster names
k_means_output = k_means_output.with_columns(
    pl.col("Cluster")
    .map_elements(lambda x: cluster_names.get(x, "Unknown"), return_dtype=pl.Utf8)
    .alias("K_Means_Cluster")
)

# %%
# create k-means summary table
k_means_summary = (
    k_means_output.group_by("K_Means_Cluster")
    .agg(
        pl.len().alias("Count"),
        pl.col("Recency").mean().round(2),
        pl.col("Frequency").mean().round(2),
        pl.col("Monetary").mean().round(2),
    )
    .sort("Monetary")
)
k_means_summary
# Out:
# shape: (4, 5)
# ┌───────────────────┬───────┬─────────┬───────────┬───────────┐
# │ K_Means_Cluster   ┆ Count ┆ Recency ┆ Frequency ┆ Monetary  │
# │ ---               ┆ ---   ┆ ---     ┆ ---       ┆ ---       │
# │ str               ┆ u32   ┆ f64     ┆ f64       ┆ f64       │
# ╞═══════════════════╪═══════╪═════════╪═══════════╪═══════════╡
# │ One_Time_Shoppers ┆ 1098  ┆ 240.2   ┆ 1.54      ┆ 469.58    │
# │ Steady_Buyers     ┆ 2988  ┆ 40.92   ┆ 3.59      ┆ 1300.49   │
# │ Elite_Spenders    ┆ 196   ┆ 16.05   ┆ 21.57     ┆ 12703.14  │
# │ VIP_Customers     ┆ 11    ┆ 5.36    ┆ 90.36     ┆ 121248.73 │
# └───────────────────┴───────┴─────────┴───────────┴───────────┘

# %%
# k_means_output.filter(pl.col("K_Means_Cluster").eq("VIP_Customers")).sort("CustomerID")

# %%
fig, ax = plt.subplots(figsize=(12, 6), facecolor="white")
ax.set_facecolor("#f2f2f2")

segments = k_means_summary["K_Means_Cluster"].to_list()
monetary = k_means_summary["Monetary"].to_list()
colors = plt.cm.tab10.colors  # fallback palette

bars = ax.bar(segments, monetary, color=colors[: len(segments)])

# Add value labels above bars
for bar, value in zip(bars, monetary):
    ax.text(
        bar.get_x() + bar.get_width() / 2,
        bar.get_height() + 500,
        f"{value:,.0f}",
        ha="center",
        va="bottom",
        fontsize=9,
        weight="bold",
    )

ax.set_title("Monetary Value per RFM Segment", fontsize=14, weight="bold")
ax.set_xlabel("Customer Segment", fontsize=12)
ax.set_ylabel("Total Monetary Value", fontsize=12)
ax.tick_params(axis="x", rotation=45)
ax.grid(axis="y", linestyle="--", alpha=0.4)

plt.tight_layout()
plt.show()

# %%
# create new column: average basket size
k_means_summary = k_means_summary.with_columns(
    pl.col("Monetary")
    .truediv(pl.col("Frequency"))
    .round(2)
    .alias("Average_Basket_Value")
)

# %%
# Creating the fourth plot: Frequency to Monetary Ratio per segment
fig, ax = plt.subplots(figsize=(12, 6), facecolor="white")
ax.set_facecolor("#f2f2f2")

segments = k_means_summary["K_Means_Cluster"].to_list()
avg_basket = k_means_summary["Average_Basket_Value"].to_list()
colors = plt.cm.tab10.colors  # Or define your own if you want fixed mapping

bars = ax.bar(segments, avg_basket, color=colors[: len(segments)])

# Add value labels
for bar, val in zip(bars, avg_basket):
    ax.text(
        bar.get_x() + bar.get_width() / 2,
        bar.get_height() + 20,
        f"{val:,.0f}",
        ha="center",
        va="bottom",
        fontsize=9,
        weight="bold",
    )

ax.set_title("Frequency to Monetary Ratio per Cluster", fontsize=14, weight="bold")
ax.set_xlabel("Customer Segment", fontsize=12)
ax.set_ylabel("Average Basket Value", fontsize=12)
ax.tick_params(axis="x", rotation=45)
ax.grid(axis="y", linestyle="--", alpha=0.4)

plt.tight_layout()
plt.show()
